# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
import yfinance as yf

# %%
pfizer=yf.download("PFE",start="2019-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
amazon=yf.download("AMZN", start="2019-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple=yf.download("AAPL", start="2019-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
exxon=yf.download("XOM", start="2019-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
nike=yf.download("NKE", start="2019-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tesla=yf.download("TSLA", start="2019-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-02   20.406668   21.008667   19.920000   20.674667   20.674667
# 2019-01-03   20.466667   20.626667   19.825333   20.024000   20.024000
# 2019-01-04   20.400000   21.200001   20.181999   21.179333   21.179333
# 2019-01-07   21.448000   22.449333   21.183332   22.330667   22.330667
# 2019-01-08   22.797333   22.934000   21.801332   22.356667   22.356667
# ...                ...         ...         ...         ...         ...
# 2023-08-14  235.699997  240.660004  233.750000  239.759995  239.759995
# 2023-08-15  238.729996  240.500000  232.610001  232.960007  232.960007
# 2023-08-16  228.020004  233.970001  225.380005  225.600006  225.600006
# 2023-08-17  226.059998  226.740005  218.830002  219.220001  219.220001
# 2023-08-18  214.119995  217.580002  212.360001  215.490005  215.490005
#
#                Volume
# Date
# 2019-01-02  174879000
# 2019-01-03  104478000
# 2019-01-04  110911500
# ...

# %%
ticks=["PFE", "AMZN", "AAPL", "XOM", "NKE", "TSLA"]

# %%
rez=yf.download(ticks,start="2019-01-01")
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
rez
# Out:
#              Adj Close                                                 \
#                   AAPL        AMZN         NKE        PFE        TSLA
# Date
# 2019-01-02   37.943256   76.956497   70.848526  34.349564   20.674667
# 2019-01-03   34.163826   75.014000   69.595329  33.388569   20.024000
# 2019-01-04   35.622257   78.769501   71.412956  34.151012   21.179333
# 2019-01-07   35.542976   81.475502   72.436546  34.333672   22.330667
# 2019-01-08   36.220524   82.829002   73.402740  34.492523   22.356667
# ...                ...         ...         ...        ...         ...
# 2023-08-14  179.460007  140.570007  107.639999  36.070000  239.759995
# 2023-08-15  177.449997  137.669998  106.550003  35.389999  232.960007
# 2023-08-16  176.570007  135.070007  106.529999  35.480000  225.600006
# 2023-08-17  174.000000  133.979996  105.050003  36.509998  219.220001
# 2023-08-18  174.490005  133.220001  104.809998  36.660000  215.490005
#
# ...

# %%
adj=yf.download(ticks,start="2019-01-01", rounding=True)["Adj Close"]
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
adj
# Out:
#               AAPL    AMZN     NKE    PFE    TSLA     XOM
# Date
# 2019-01-02   37.94   76.96   70.85  34.35   20.67   54.46
# 2019-01-03   34.16   75.01   69.60  33.39   20.02   53.62
# 2019-01-04   35.62   78.77   71.41  34.15   21.18   55.60
# 2019-01-07   35.54   81.48   72.44  34.33   22.33   55.89
# 2019-01-08   36.22   82.83   73.40  34.49   22.36   56.29
# ...            ...     ...     ...    ...     ...     ...
# 2023-08-14  179.46  140.57  107.64  36.07  239.76  111.01
# 2023-08-15  177.45  137.67  106.55  35.39  232.96  108.16
# 2023-08-16  176.57  135.07  106.53  35.48  225.60  106.34
# 2023-08-17  174.00  133.98  105.05  36.51  219.22  108.40
# 2023-08-18  174.49  133.22  104.81  36.66  215.49  110.04
#
# [1166 rows x 6 columns]

# %%
close=yf.download(ticks,start="2019-01-01", rounding=True)["Close"]
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
open=yf.download(ticks,start="2019-01-01", rounding=True)["Open"]
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
high=yf.download(ticks,start="2019-01-01", rounding=True)["High"]
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
low=yf.download(ticks,start="2019-01-01", rounding=True)["Low"]
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
import seaborn as sns

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
correlation_matrix=adj.corr()

# %%
correlation_matrix
# Out:
#           AAPL      AMZN       NKE       PFE      TSLA       XOM
# AAPL  1.000000  0.559516  0.707924  0.689587  0.909674  0.536383
# AMZN  0.559516  1.000000  0.799809  0.212232  0.696956 -0.332607
# NKE   0.707924  0.799809  1.000000  0.500868  0.791813  0.014984
# PFE   0.689587  0.212232  0.500868  1.000000  0.712981  0.590373
# TSLA  0.909674  0.696956  0.791813  0.712981  1.000000  0.330862
# XOM   0.536383 -0.332607  0.014984  0.590373  0.330862  1.000000

# %%
G=nx.Graph()
for pod in adj:
  G.add_node(pod)

# %%
for pod1 in adj:
  for pod2 in adj:
    if pod1 != pod2:
      corellation = correlation_matrix.loc[pod1,pod2]
      if abs(corellation)>=0.5:
        G.add_edge(pod1,pod2, weight=corellation)

# %%
plt.figure(figsize=(8,6))

# %%
pos=nx.spring_layout(G)

# %%
nx.draw(G,pos,with_labels=True, font_weight='bold', node_size=1500, node_color='lightgreen')

# %%
G_layout = nx.layout.fruchterman_reingold_layout(G)

# %%
import holoviews as hv
from holoviews import opts
hv.extension('bokeh')
from bokeh.plotting import show

defaults = dict(width=750, height=750, padding=0.1,
                xaxis=None, yaxis=None)
hv.opts.defaults(
    opts.EdgePaths(**defaults), opts.Graph(**defaults), opts.Nodes(**defaults))
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
cent_between = nx.betweenness_centrality(G)
sorted(cent_between.items(),key=lambda x:-x[1])[:10]
# Out:
# [('AAPL', 0.2333333333333333),
#  ('PFE', 0.1),
#  ('NKE', 0.03333333333333333),
#  ('TSLA', 0.03333333333333333),
#  ('AMZN', 0.0),
#  ('XOM', 0.0)]

# %%
nx.set_node_attributes(G, cent_between, 'cent_between')

g_plot = hv.Graph.from_networkx(G, G_layout).opts(tools=['hover'],
                                                  node_size='cent_between' )

show(hv.render(g_plot))
# Out:
#   <div id="c8c0be55-69e2-40f3-96a3-ef83ca827887" data-root-id="p1728" style="display: contents;"></div>

# %%
cent_eigen = dict(nx.eigenvector_centrality(G))

# %%
sorted(cent_eigen.items(),key=lambda x:-x[1])[:10]
# Out:
# [('AAPL', 0.4935321496582701),
#  ('NKE', 0.4448236152122262),
#  ('TSLA', 0.4448236152122262),
#  ('PFE', 0.41976476978095234),
#  ('AMZN', 0.3584334023636393),
#  ('XOM', 0.2366705602171654)]

# %%
nx.set_node_attributes(G, cent_eigen, 'cent_eigen')

g_plot = hv.Graph.from_networkx(G, G_layout).opts(tools=['hover'],
                                                  node_size='cent_eigen' )

show(hv.render(g_plot))
# Out:
#   <div id="da6499ad-ccdd-403c-a536-7c185562d416" data-root-id="p2130" style="display: contents;"></div>

# %%
cent_degree = dict(nx.degree(G))

# %%
cent_degree.values()
# Out:
# dict_values([5, 3, 4, 4, 4, 2])

# %%
sorted(cent_degree.items(),key=lambda x:-x[1])[:10]
# Out:
# [('AAPL', 5), ('NKE', 4), ('PFE', 4), ('TSLA', 4), ('AMZN', 3), ('XOM', 2)]

# %%
nx.set_node_attributes(G, cent_degree, 'cent_degree')

g_plot = hv.Graph.from_networkx(G, G_layout).opts(tools=['hover'],
                                                  node_size=50)

show(hv.render(g_plot))
# Out:
#   <div id="fdc77d9c-dffa-4c41-b0e5-d2e94db71dd2" data-root-id="p1970" style="display: contents;"></div>

# %%
nx.closeness_centrality(G)
# Out:
# {'AAPL': 1.0,
#  'AMZN': 0.7142857142857143,
#  'NKE': 0.8333333333333334,
#  'PFE': 0.8333333333333334,
#  'TSLA': 0.8333333333333334,
#  'XOM': 0.625}
